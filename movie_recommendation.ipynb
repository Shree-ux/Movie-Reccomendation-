# %%
import random

def calculate_movie_rating(genre, stars, industries, director, production):
  """Calculates a movie rating based on provided attributes."""

  # Base Rating
  base_ratings = {
    "Sci-Fi": 7,
    "Action": 6,
    "Comedy": 6,
    "Drama": 6,
    "Horror": 5,
    "Romance": 6,
    "Animation": 7,
    "Other": 5
  }
  base_rating = base_ratings.get(genre, 5)  # Default to 5 if genre is not found

  # Star Power
  star_power = 0
  for star in stars:
    if star == "A-List":
      star_power += 2
    elif star == "B-List":
      star_power += 1
    else:
      star_power += 0.5

  # Industry Diversity
  industry_diversity_bonus = 1 if len(industries) > 1 else 0

  # Director Influence
  director_bonus = 1 if director == "Highly Acclaimed" else (0.5 if director == "Emerging" else 0)

  # Production Quality
  production_bonus = 1 if "High Budget" in production else 0
  production_bonus += 0.5 if "Special Effects Heavy" in production else 0
  production_bonus += 0.5 if "Visually Striking" in production else 0

  # Uniqueness Rating
  uniqueness_rating = random.uniform(0.1, 0.9)

  # Total Rating
  total_rating = base_rating + star_power + industry_diversity_bonus + director_bonus + production_bonus + uniqueness_rating

  # Round to the nearest tenth
  return round(total_rating, 1)

# Get movie details from the user
movies = []
for i in range(10):A
  genre = input(f"Enter genre for movie {i+1}: ")
  stars = input(f"Enter star ratings (A-List, B-List, Unfamiliar) for movie {i+1}, separated by commas: ").split(",")
  industries = input(f"Enter film industries for movie {i+1}, separated by commas: ").split(",")
  director = input(f"Enter director's status (Highly Acclaimed, Emerging, Other) for movie {i+1}: ")
  production = input(f"Enter production details (High Budget, Special Effects Heavy, Visually Striking) for movie {i+1}, separated by commas: ").split(",")

  movies.append({
    "title": f"Movie {i+1}",
    "genre": genre,
    "stars": stars,
    "industries": industries,
    "director": director,
    "production": production
  })

# Calculate and display ratings
for movie in movies:
  rating = calculate_movie_rating(movie["genre"], movie["stars"], movie["industries"], movie["director"], movie["production"])
  print(f"{movie['title']} - Rating: {rating}")
# Out:
# Enter genre for movie 1: Action
# Enter star ratings (A-List, B-List, Unfamiliar) for movie 1, separated by commas: A-List
# Enter film industries for movie 1, separated by commas: 1
# Enter director's status (Highly Acclaimed, Emerging, Other) for movie 1: highly acclaimed
# Enter production details (High Budget, Special Effects Heavy, Visually Striking) for movie 1, separated by commas: special effects heavy
# Enter genre for movie 2: horror
# Enter star ratings (A-List, B-List, Unfamiliar) for movie 2, separated by commas: B-list
# Enter film industries for movie 2, separated by commas: 2
# Enter director's status (Highly Acclaimed, Emerging, Other) for movie 2: highly acclaimed
# Enter production details (High Budget, Special Effects Heavy, Visually Striking) for movie 2, separated by commas: high budget
# Enter genre for movie 3: drama
# Enter star ratings (A-List, B-List, Unfamiliar) for movie 3, separated by commas: unfamilair
# ...

# %%
import random

def calculate_movie_rating(genre, stars, industries, director, production):
  """Calculates a movie rating based on provided attributes."""

  # ... (rest of the function code remains the same)

# Get movie details from the user
movies = []
for i in range(10):
  movie_name = input(f"Enter movie name for movie {i+1}: ")  # Add movie name input
  genre = input(f"Enter genre for movie {i+1}: ")
  stars = input(f"Enter star ratings (A-List, B-List, Unfamiliar) for movie {i+1}, separated by commas: ").split(",")  # User enters comma-separated values
  industries = input(f"Enter film industries for movie {i+1}, separated by commas: ").split(",")  # User enters comma-separated values
  director = input(f"Enter director's status (Highly Acclaimed, Emerging, Other) for movie {i+1}: ")
  production = input(f"Enter production details (High Budget, Special Effects Heavy, Visually Striking) for movie {i+1}, separated by commas: ").split(",") # User enters comma-separated values

  movies.append({
    "title": movie_name,  # Store the movie name
    "genre": genre,
    "stars": stars,
    "industries": industries,
    "director": director,
    "production": production
  })

# Calculate and display ratings
for movie in movies:
  rating = calculate_movie_rating(movie["genre"], movie["stars"], movie["industries"], movie["director"], movie["production"])
  print(f"{movie['title']} - Rating: {rating}")
# Out:
# Enter movie name for movie 1: top gun
# Enter genre for movie 1: Action
# Enter star ratings (A-List, B-List, Unfamiliar) for movie 1, separated by commas: B
# Enter film industries for movie 1, separated by commas: aser
# Enter director's status (Highly Acclaimed, Emerging, Other) for movie 1: harshan
